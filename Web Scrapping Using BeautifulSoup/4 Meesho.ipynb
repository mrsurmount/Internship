# %% [markdown]
# # Ques. 4 -  Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7v

# %%
# !pip install bs4
# !pip install requests
import pandas as pd

# %%
from bs4 import BeautifulSoup
import requests

# %%
page1 = requests.get('https://meesho.com/bags-ladies/pl/p7vbp')
page1
# Out:
# <Response [200]>

# %%
soup =  BeautifulSoup(page1.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-2">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-6">
#   </script>
#   <script async="">
#    window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'UA-113318580-2', {
#                 page_path: window.location.pathname,
#               });
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-ZB97HR591S">
#   </script>
#   <script async="">
#    window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'G-ZB97HR591S', {
#                 page_path: window.location.pathname,
#               });
#   </script>
#   <script async="">
# ...

# %%
product_name = []
for i in soup.find_all('p', class_="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS"):
    product_name.append(i.text)
product_name
# Out:
# ['Women PINK Shoulder Bag - Extra Spacious',
#  'Sketch  Leather Tote Bag',
#  'JUTE-TFLY-01cRED-5 handbag',
#  'Elegant Fashionable Women Handbags',
#  'Gorgeous Attractive Women Handbags',
#  'X-DIAMOND ,PINK,STONE, HANDBANG,PACK OF 1',
#  'Jute White Color Floral Printed Fancy Bag, Beach Bag, Shopping Bag, spacious Bag, Trendy Women Bag, Casual Bag with Zipper Closer',
#  'Latest design combo handbag set',
#  'hand bag with golden chain',
#  'X-DIAMOND ,FOREVER FASHION,CLUTCHES,PACK OF 6',
#  'Hand bag',
#  'Voguish Fancy Women Handbags',
#  'Hand bag',
#  'Hand bag for women/hand bag/ solid print  bag/stylish handbag/wedding bag/handbag set for women ',
#  'Leather Women Stylish Handbag/purse | Shoulder Hanbags for College Office Girls - Blue',
#  'Graceful Versatile Women Handbags',
#  'Leather Women Stylish Handbag/purse | Shoulder Hanbags for College Office Girls - Brown',
#  'Leather Women Stylish Handbag/purse | Shoulder Hanbags for College Office Girls - Gray',
# ...

# %%
price = []
for i in soup.find_all('h5', class_="Text__StyledText-sc-oo0kvp-0 hiHdyy"):
    price.append(i.text)
price
# Out:
# ['₹194',
#  '₹985',
#  '₹1085',
#  '₹224',
#  '₹900',
#  '₹295',
#  '₹400',
#  '₹348',
#  '₹224',
#  '₹369',
#  '₹286',
#  '₹1600',
#  '₹224',
#  '₹365',
#  '₹187',
#  '₹600',
#  '₹187',
#  '₹187',
#  '₹899',
#  '₹266']

# %%
discounts = []
for i in soup.find_all('p',class_='Text__StyledText-sc-oo0kvp-0 fCJVtz NewProductCard__DiscountTextParagraph-sc-j0e7tu-16 kmYsnm NewProductCard__DiscountTextParagraph-sc-j0e7tu-16 kmYsnm'):
    discounts.append(i.text)
discounts
# Out:
# ['₹82 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹96 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹96 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹96 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹79 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹79 discount on 1st order',
#  '₹79 discount on 1st order',
#  '₹100 discount on 1st order',
#  '₹100 discount on 1st order']

# %%
df = pd.DataFrame()
df['Product name'] = product_name
df['Price'] = price
df['Discounts'] = discounts
df
# Out:
#                                          Product name  Price  \
# 0            Women PINK Shoulder Bag - Extra Spacious   ₹194
# 1                            Sketch  Leather Tote Bag   ₹985
# 2                          JUTE-TFLY-01cRED-5 handbag  ₹1085
# 3                  Elegant Fashionable Women Handbags   ₹224
# 4                  Gorgeous Attractive Women Handbags   ₹900
# 5           X-DIAMOND ,PINK,STONE, HANDBANG,PACK OF 1   ₹295
# 6   Jute White Color Floral Printed Fancy Bag, Bea...   ₹400
# 7                     Latest design combo handbag set   ₹348
# 8                          hand bag with golden chain   ₹224
# 9       X-DIAMOND ,FOREVER FASHION,CLUTCHES,PACK OF 6   ₹369
# 10                                           Hand bag   ₹286
# 11                       Voguish Fancy Women Handbags  ₹1600
# 12                                           Hand bag   ₹224
# 13  Hand bag for women/hand bag/ solid print  bag/...   ₹365
# ...

# %%
#df.to_csv('meesho.csv',index=False)
