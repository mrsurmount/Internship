# %% [markdown]
# Importing the Required Libraries

# %%
import selenium
from selenium import webdriver
import time
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# Opening the Browser

# %%
driver = webdriver.Chrome('chromedriver1.exe')

# %% [markdown]
# ## Quesn. 1  Scrape the details of most viewed videos on YouTube from Wikipedia.
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos' # Opening the URL
driver.get(url)
time.sleep(2)

# %%
rank = []            #Empty List for all the data I want to extract
name=[]
artist =[]
date=[]
views=[]

ran=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')   #Xpath of the element, what I want to extract.
nam=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
art=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
dat=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')
vie=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')

for i in ran:
    rank.append(i.text)           #Appening the text data, in the webelements
for j in nam:
    name.append(j.text)
for k in art:
    artist.append(k.text)
for l in dat:
    date.append(l.text)
for m in vie:
    views.append(m.text)
        
print(len(rank))                    #Printing the length of the data
print(len(name))                 
print(len(artist))
print(len(date))
print(len(views))
# Out:
# 30
# 30
# 30
# 30
# 30

# %% [markdown]
# Creating the dataframe

# %%
df = pd.DataFrame({'Rank':rank,                              
                 'Name':name,
                 'Artist':artist,
                 'Date':date,
                 'Views':views})
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[21]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[22]
# 8    9.                "Phonics Song with Two Words"[23]
# 9   10.                                "Uptown Funk"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                             "Dame Tu Cosita"[30]
# 12  13.                          "Wheels on the Bus"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %% [markdown]
# ## Ques. 2  Scrape the details team India’s international fixtures from bcci.tv.
#
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time

# %%
url1 = 'https://www.bcci.tv/'              #Opening the URL
driver.get(url1)
time.sleep(2)

# %%
international = driver.find_element_by_xpath('//li[@class="nav-item ml-0"]/a')   #Clicking on international, SO that I can reach on the required page, from where I have to extract the data.
international.click()

# %%
try:
    for page in range(200):                           #Scrolling the page down and opening till the end of the page, So that I can extract all the details of the page.
        driver.execute_script("window.scrollBy(0,100)")
        more = driver.find_element_by_xpath('//div[@class="col-lg-12 col-md-12 col-sm-12"]/button')
        more.click()
except:
    pass

# %%
series = []             # Giving the empty list for all the coloumn, what all I want to extract
odi = [] 
date = []
time = []
place = []
     
ser = driver.find_elements_by_xpath('//h5[@class="fix-text"][2]/span')            #Giving the xpath of the required data what I want to extract
od = driver.find_elements_by_xpath('//div[@class="fix-place ng-binding ng-scope"]/span[1]')
da = driver.find_elements_by_xpath('//div[@class="match-card-left match-schedule"]')
ti = driver.find_elements_by_xpath('//div[@class="match-card-right match-schedule "]')
pla = driver.find_elements_by_xpath('//div[@class="fix-place ng-binding ng-scope"]/span[2]')

for i in ser:
    series.append(i.text)                    # Appending the text data
for j in od:
    odi.append(j.text.replace('-',''))
for k in da:
    date.append(k.text)
for l in ti:
    time.append(l.text)
for m in pla:
    place.append(m.text)
    
print(len(series))            # Printing the length of the all the data what, I have extracted
print(len(odi))
print(len(date))
print(len(time))
print(len(place))
# Out:
# 19
# 19
# 19
# 19
# 19

# %% [markdown]
# Creating the DataFrame of the data

# %%
df2 = pd.DataFrame({'Match Title':odi,
                   'Series':series,
                   'Place':place,
                   'Date':date,
                   'time':time})
df2
# Out:
#    Match Title                                           Series  \
# 0     4th ODI   INDIA WOMEN TOUR OF NEW ZEALAND ODI SERIES 2022
# 1     5th ODI   INDIA WOMEN TOUR OF NEW ZEALAND ODI SERIES 2022
# 2    1st T20I           SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 3    2nd T20I           SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 4    3rd T20I           SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 5    1st Test          SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 6     1st ODI                         ICC WOMENS WORLD CUP 2022
# 7     2nd ODI                         ICC WOMENS WORLD CUP 2022
# 8    2nd Test          SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 9     3rd ODI                         ICC WOMENS WORLD CUP 2022
# 10    4th ODI                         ICC WOMENS WORLD CUP 2022
# 11    5th ODI                         ICC WOMENS WORLD CUP 2022
# 12    6th ODI                         ICC WOMENS WORLD CUP 2022
# 13    7th ODI                         ICC WOMENS WORLD CUP 2022
# ...

# %% [markdown]
# ## Ques. 3  Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description

# %%
url2 = 'https://www.guru99.com/'  # Giving the URL
driver.get(url2)
time.sleep(5)
selenium = driver.find_element_by_xpath('//ul[@class="menu1"]/li[3]')        # Clicking on Selenium, in the website
selenium.click()

# %%
exception = driver.find_element_by_xpath('//table[@class="table"][5]/tbody/tr[34 ]/td[1]')      #Clicking on the required element, So, that I can reach to the page from where I have to extract the data.
exception.click()

# %%
name = []               # Giving the empty list
description = []

nam = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')      #Giving the Xpath   
des = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')

for i in nam:
    name.append(i.text)                 #Appending the text data
for j in des:
    description.append(j.text)
print(len(name))                #Printing the length
print(len(description))
# Out:
# 41
# 41

# %% [markdown]
# Creating the DataFrame

# %%
df3 = pd.DataFrame({'Name':name,'Description':description})
df3
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# ## Ques 4  Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP
#
# D) GSDP
#
# E) Share
#
# F) GDP($ billion)

# %%
url3 = 'http://statisticstimes.com/'   #Giving the URL
driver.get(url3)
time.sleep(5)

# %%
economy = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button')       #Giving the Xpath
economy.click()
time.sleep(5)
india = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
india.click()
gdp = driver.find_element_by_xpath('//ul[@style="list-style-type:none;margin-left:20px;"]//li[1]/a')
gdp.click()

# %%
rank = []              #Giving the empty list for all the coloumnns, what all I want to extract
state = []
gsdp_19_20 = []
gsdp_18_19 = []
share = []
gdp = []
gsdp2_19_20 = []
gsdp2_18_19 = []

ran = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//td[1]')            #Giving the Xpath
sta = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//td[2]')
gs1 = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//td[3]')
gs2 = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//td[4]')
sha = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//td[5]')
gd = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//td[6]')
gs3 = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//td[7]')
gs4 = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//td[8]')

for i in ran:
    rank.append(i.text)                               #Appending the text data.
for j in sta:
    state.append(j.text)
for k in gs1:
    gsdp_19_20.append(k.text)
for l in gs2:
    gsdp_18_19.append(l.text)
for m in sha:
    share.append(m.text)
for n in gd:
    gdp.append(n.text)
for o in gs3:
    gsdp2_19_20.append(o.text)
for p in gs4:
    gsdp2_18_19.append(p.text)
    
print(len(rank))                             #Printing the length of all the data, what all I have extracted
print(len(state))
print(len(gsdp_19_20))
print(len(gsdp_18_19))
print(len(share))
print(len(gdp))
print(len(gsdp2_19_20))
print(len(gsdp2_18_19))
# Out:
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33

# %% [markdown]
# Creating the DataFrame

# %%
df4 = pd.DataFrame({'Rank':rank,
                   'State':state,
                   'GSDP(Cr INR at Current prices)(19-20)':gsdp_19_20,
                  'GSDP(Cr INR at Current prices)(18-19)':gsdp_18_19,
                  'Share':share,
                   'GDP($billion)':gdp,
                   'GSDP(Cr INR at 2011-12 prices)(19-20)':gsdp2_19_20,
                   'GSDP(Cr INR at 2011-12 prices)(18-19)':gsdp2_18_19})
df4
# Out:
#    Rank                      State GSDP(Cr INR at Current prices)(19-20)  \
# 0     1                Maharashtra                                     -
# 1     2                 Tamil Nadu                             1,845,853
# 2     3              Uttar Pradesh                             1,687,818
# 3     4                    Gujarat                                     -
# 4     5                  Karnataka                             1,631,977
# 5     6                West Bengal                             1,253,832
# 6     7                  Rajasthan                             1,020,989
# 7     8             Andhra Pradesh                               972,782
# 8     9                  Telangana                               969,604
# 9    10             Madhya Pradesh                               906,672
# 10   11                     Kerala                                     -
# 11   12                      Delhi                               856,112
# ...

# %% [markdown]
# ## Ques. 5 Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used

# %%
url4 = 'https://github.com/'       #Giving the URL
driver.get(url4)
time.sleep(3)

# %%
#Clicking on explore button then on trending, So that I can lend to the required page, From where I have to extract the data.

explore = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
explore.click()
time.sleep(2)
trending = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
trending.click()

# %%
title = []                # Giving the empty list
description = []
contributer = []

soup=BeautifulSoup(driver.page_source,'html.parser')         #Used the concept of BeautifulSoup, and extracted the data.
t = soup.find_all('h1',attrs={'h3 lh-condensed'})
d = soup.find_all('article',attrs={'Box-row'})
c = soup.find_all('div',attrs={'f6 color-fg-muted mt-2'})

for i in t:                                                 #used for loop, So that all the data what I have extracted in, It can be converted into text,as I have done below.
    try:                                                    #used try and except method. So, that where No data is present, I can mention, "No details available"
        title.append(i.find('span').text.strip('\n'))       #Appending the text data
    except AttributeError:
        title.append("No details available")
for j in d:
    try:
        description.append(j.find('p').text.split('\n')[-2])
    except AttributeError:
        description.append("No details available")
for k in c:
    try:
        contributer.append(k.find('a').text)
    except AttributeError:
        contributer.append("No details available")

print(len(title))                                      #Printing the length 
print(len(description))
print(len(contributer))
# Out:
# 25
# 25
# 25

# %%
urls = []                 #Giving the empty list for the URL's

links = driver.find_elements_by_xpath('//article[@class="Box-row"]//h1//a')         #Giving the Xpath for each repositories

for url in links:
    urls.append(url.get_attribute('href'))          #Extracting the url's for the repositories.              
urls
# Out:
# ['https://github.com/Anduin2017/HowToCook',
#  'https://github.com/NVlabs/instant-ngp',
#  'https://github.com/yt-dlp/yt-dlp',
#  'https://github.com/coding-horror/basic-computer-games',
#  'https://github.com/odin-lang/Odin',
#  'https://github.com/emilk/egui',
#  'https://github.com/martinvonz/jj',
#  'https://github.com/adrianhajdin/project_professional_portfolio',
#  'https://github.com/lwthiker/curl-impersonate',
#  'https://github.com/danistefanovic/build-your-own-x',
#  'https://github.com/doocs/advanced-java',
#  'https://github.com/BlueWallet/BlueWallet',
#  'https://github.com/supabase/supabase',
#  'https://github.com/freeCodeCamp/freeCodeCamp',
#  'https://github.com/cryptotwinsbr/spacecrypto-bot',
#  'https://github.com/harmonoid/harmonoid',
#  'https://github.com/withfig/autocomplete',
#  'https://github.com/myugan/awesome-docker-security',
#  'https://github.com/BuilderIO/qwik',
#  'https://github.com/danielbeach/data-engineering-practice',
# ...

# %%
repository_title = []                    #Giving the Empty List
repository_description = []
contributors_count = []
language_used = []

for i in urls:
    driver.get(i)                        #Iterating into each URl's and extracting the required data.
    time.sleep(3)
    try:
        title = driver.find_element_by_xpath('//h1[@class=" d-flex flex-wrap flex-items-center wb-break-word f3 text-normal"]/span[1]')
        repository_title.append(title.text.replace('\n',''))             #Appending the text data and Replacing the unrequired data
    except NoSuchElementException:
        repository_title.append('-')                         #Used try and except. So, that in case, I data is not there then also our code get's executed without giving error.
        
    time.sleep(1)
    try:
        descrip = driver.find_element_by_xpath('//div[@class="BorderGrid-cell"]//p')
        repository_description.append(descrip.text.replace('\n',''))
    except NoSuchElementException:
        repository_description.append('-')

    time.sleep(1)
    try:
        count = driver.find_element_by_xpath("//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        contributors_count.append(count.text)
        
    except NoSuchElementException:
        contributors_count.append('-')
    time.sleep(1)
    try:
        lang = driver.find_element_by_xpath('//li[@class="d-inline"]//a//span')
        language_used.append(lang.text.replace('\n',''))
    except NoSuchElementException:
        language_used.append('-')

# %% [markdown]
# Creating the DataFrame

# %%
github = pd.DataFrame({})
github['repository_title'] = repository_title
github['repository_description'] = repository_description
github['contributors_count']  = contributors_count
github['language_used'] = language_used
github
# Out:
#    repository_title                             repository_description  \
# 0        Anduin2017                                       程序员在家做饭方法指南。
# 1            NVlabs  Instant neural graphics primitives: lightning ...
# 2            yt-dlp  A youtube-dl fork with additional features and...
# 3     coding-horror  An updated version of the classic "Basic Compu...
# 4         odin-lang                          Odin Programming Language
# 5             emilk  egui: an easy-to-use immediate mode GUI in Rus...
# 6        martinvonz  A Git-compatible DVCS that is both simple and ...
# 7      adrianhajdin  This is a code repository for the correspondin...
# 8          lwthiker  curl-impersonate: A special compilation of cur...
# 9    danistefanovic          🤓 Build your own (insert technology here)
# 10            doocs  😮 Core Interview Questions & Answers For Exper...
# 11       BlueWallet  Bitcoin thin client for iOS & Android. Built w...
# ...

# %% [markdown]
# ## Ques. 6 Scrape the details of top 100 songs on billiboard.com.
#
# Url = https:/www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board

# %%
url5 = 'https:/www.billboard.com/'     # giving the url
driver.get(url5)
time.sleep(5)

# %%
#Clicking on 'hot' button
hot = driver.find_element_by_xpath('//div[@class="lrv-u-flex lrv-u-background-color-white u-height-45"]//li[1]')
hot.click()

# %%
songs = []       #Giving the empty list for all the coloumns, what all I want to extract.
artists = []
last = []
peak = []
board = []

song = driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]//h3')    #Giving the xpath for all the columns, what all I want to extract.
art = driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]/ul/li[1]//span[1]')
las = driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]/ul/li[4]')
pea = driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]/ul/li[5]')
boa = driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]/ul/li[6]')

for i in song:
    songs.append(i.text)
for j in art:
    artists.append(j.text)
for k in las:
    last.append(k.text)
for l in pea:
    peak.append(l.text)
for m in boa:
    board.append(m.text)

print(len(songs))       #Printing the length for all the columns.
print(len(artists))
print(len(last))
print(len(peak))
print(len(board))
# Out:
# 100
# 100
# 100
# 100
# 100

# %% [markdown]
# Creating the DataFrame

# %%
df6 = pd.DataFrame({'Songs':songs,
                   'Artist':artists,
                   'Last Week Rank':last,
                   'Peak rank':peak,
                   'Weeks on board':board})
df6
# Out:
#                         Songs  \
# 0   We Don't Talk About Bruno
# 1       Do We Have A Problem?
# 2                  Easy On Me
# 3                  Heat Waves
# 4                        Stay
# ..                        ...
# 95                       Iffy
# 96              When I'm Gone
# 97                 Fair Trade
# 98              Megan's Piano
# 99            Moth To A Flame
#
#                                                Artist Last Week Rank  \
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...              1
# 1                              Nicki Minaj X Lil Baby              -
# 2                                               Adele              2
# 3                                       Glass Animals              3
# 4                       The Kid LAROI & Justin Bieber              4
# ..                                                ...            ...
# 95                                        Chris Brown             87
# ...

# %% [markdown]
# ## Ques. 7  Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/data-collection-recruiters
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they

# %%
url6 = 'https://www.naukri.com/data-collection-recruiters'  #Giving the url
driver.get(url6)

# %%
search = driver.find_element_by_xpath('//*[@id="skill"]/div[1]/div[2]/input') #Giving the xpath for the search button
search.clear()
search.send_keys('Data Scientist')              #sending the data to be typed in the search box.
time.sleep(2)
searchh = driver.find_element_by_xpath('//*[@id="qsbFormBtn"]')   #Clicking on the 'Search' button.
searchh.click()

# %%
name = []           #Giving the empty list
designation = [] 
company = []
skills = []

nam = driver.find_elements_by_xpath('//div[@class="recInfo"]/div[1]/p/a/span')     #Giving the Xpath for all the columns
desi = driver.find_elements_by_xpath('//div[@class="recInfo"]/div[1]/p/span[1]')
comp = driver.find_elements_by_xpath('//div[@class="recInfo"]/div[1]/p/a[2]')
skill = driver.find_elements_by_xpath('//div[@class="recInfo"]/div[2]')

for i in nam:                  
    name.append(i.text)                                 #Iterating the text data
for j in desi:
    designation.append(j.text)
for k in comp:
    company.append(k.text)
for n in skill:
    skills.append(n.text)

print(len(name))                                #Printing the length of the data
print(len(designation))
print(len(company))
print(len(skills))
# Out:
# 50
# 50
# 50
# 50

# %%
# Used the concept of BeautifulSoup, So that I can use try and except method, As in selenium try and except was not working properly. 
location=[]            
soup=BeautifulSoup(driver.page_source,'html.parser')      #Gave the page source
l=soup.find_all('div',attrs={'vcard'})                    #Gave the class name and the attribute name
for i in l:
    try:                                         #Used Try and except method
        location.append(i.find('small').text)              #Appending the text data
    except AttributeError :
        location.append("No details available")
print(len(location))
# Out:
# 50

# %% [markdown]
# Creating the DataFrame

# %%
df7 = pd.DataFrame({'Name':name,
                   'Designation':designation,
                   'Company':company,
                   'Skills Needed':skills,
                   'Location':location})
df7
# Out:
#                                             Name  \
# 0                                      Tanushree
# 1                                  sashi bhushan
# 2                                         Bitapi
# 3                                 Gajendra Singh
# 4                              Sadashiv Kulkarni
# 5                                    Invelopment
# 6                              Anjali Srivastava
# 7                                     Helly Vyas
# 8                                   Ashish Verma
# 9                                  Shiva Kumar N
# 10                            Balaji Prabhakaran
# 11                              Bhuwneshari Devi
# 12                                    HS Sandesh
# 13                               Anoop Somarajan
# 14                                   Datafoundry
# 15                               A Valsa Florina
# 16                                 Kalaivani M V
# 17                                    Prashant K
# ...

# %% [markdown]
# ## Ques. 8  Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
url7 = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'   #Giving the Url
driver.get(url7)

# %%
title = []           #Giving the empty list for all the coloumns, what all I want to extract.
author = []
volume = []
publisher = []
genre = []

tit = driver.find_elements_by_xpath('//table[@class="in-article sortable"]//tbody//tr//td[2]')     #Giving the xpath
aut = driver.find_elements_by_xpath('//table[@class="in-article sortable"]//tbody//tr//td[3]')
vol = driver.find_elements_by_xpath('//table[@class="in-article sortable"]//tbody//tr//td[4]')
pub = driver.find_elements_by_xpath('//table[@class="in-article sortable"]//tbody//tr//td[5]')
gen = driver.find_elements_by_xpath('//table[@class="in-article sortable"]//tbody//tr//td[6]')

for i in tit:
    title.append(i.text)                                           #Appending the text data
for j in aut:
    author.append(j.text)
for k in vol:
    volume.append(k.text)
for l in pub:
    publisher.append(l.text)
for m in gen:
    genre.append(m.text)
    
print(len(title))                                          #Printing the length of all the columns.
print(len(author))
print(len(volume))
print(len(publisher))
print(len(genre))
# Out:
# 100
# 100
# 100
# 100
# 100

# %% [markdown]
# Creating the DataFrame

# %%
df8 = pd.DataFrame({'Book name':title,
                   'Author name':author,
                   'Volumes sold':volume,
                   'Publisher':publisher,
                   'Genre':genre})
df8
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %% [markdown]
# ## Ques. 9 Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
url8 = 'https://www.imdb.com/list/ls095964455'      #Giving the url
driver.get(url8)

# %%
name = []                             #Giving the empty list for all the columns, what all I want to extract
year = []
genre = []
time = []
ratings = []
votes = []

nam = driver.find_elements_by_xpath('//div[@class="lister-item-content"]/h3/a')            #Giving the Xpath
yea = driver.find_elements_by_xpath('//div[@class="lister-item-content"]/h3/span[2]')
gen = driver.find_elements_by_xpath('//p[@class="text-muted text-small"]//span[5]')
tim = driver.find_elements_by_xpath('//p[@class="text-muted text-small"]//span[3]')
rat = driver.find_elements_by_xpath('//div[@class="ipl-rating-widget"]/div/span[2]')
vot = driver.find_elements_by_xpath('//p[@class="text-muted text-small"][3]/span[2]')

for i in nam:
    name.append(i.text)                               #Iterating the text data from the data what I have extracted.
for j in yea:
    year.append(j.text)
for k in gen:
    genre.append(k.text)
for l in tim:
    time.append(l.text)
for m in rat:
    ratings.append(m.text)
for n in vot:
    votes.append(n.text)

print(len(name))                                     #Printing the length of the data
print(len(year))
print(len(genre))
print(len(time))
print(len(ratings))
print(len(votes))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100

# %% [markdown]
# Creating the DataFrame

# %%
df9 = pd.DataFrame({'Name':name,
                   'Year':year,
                   'Genre':genre,
                   'Run Time':time,
                   'Ratings':ratings,
                   'Votes':votes})
df9
# Out:
#                               Name         Year                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,954,661
# ...

# %% [markdown]
# ## Quesn. 10 Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year

# %%
url9 = 'https://archive.ics.uci.edu/'      #Giving the url
driver.get(url9)

# %%
#Clicking on 'View' button
view = driver.find_element_by_xpath('//span[@class="whitetext"][2]/a[1]')
view.click()

# %%
name = []                 #Giving the empty list for all the columns, what all I want to extract.
typee = []
task = []
attribute = []
instances = []
attributes = []
year = []

nam = driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]')     #Giving the Xpath
typ = driver.find_elements_by_xpath('//table[@cellpadding = "3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]')
tas = driver.find_elements_by_xpath('//table[@cellpadding="3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]')
attri = driver.find_elements_by_xpath('//table[@cellpadding="3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]')
inst = driver.find_elements_by_xpath('//table[@cellpadding="3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]')
attri = driver.find_elements_by_xpath('//table[@cellpadding="3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]')
yea = driver.find_elements_by_xpath('//table[@cellpadding="3"]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]')

for i in nam[1:]:                               #Used the concept of indexing to extract the desired data
    name.append(i.text)                         #Appending the text data
for j in typ[1:]:
    typee.append(j.text)
for k in tas[1:]:
    task.append(k.text)
for l in attri[1:]:
    attribute.append(l.text)
for m in inst[1:]:
    instances.append(m.text)
for n in attri[1:]:
    attributes.append(n.text)
for o in yea[1:]:
    year.append(o.text)
    
print(len(name))                          #Printing the length for all the columns
print(len(typee))
print(len(task))
print(len(attribute))
print(len(instances))
print(len(attributes))
print(len(year))
# Out:
# 622
# 622
# 622
# 622
# 622
# 622
# 622

# %% [markdown]
# Creating the DataFrame

# %%
df10 = pd.DataFrame({'Name':name,
                    'Data Types':typee,
                    'Default Task':task,
                    'Attribute Types':attribute,
                    'Number of Instances':instances,
                    'Number of Attributes':attributes,
                    'Year':year})
df10
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617    Influenza outbreak event prediction via Twit...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621    Image Recognition Task Execution Times in Mo...
#
#                      Data Types          Default Task Attribute Types  \
# 0                 Multivariate        Classification               8
# 1                 Multivariate        Classification              14
# 2                 Multivariate        Classification              38
# ...
